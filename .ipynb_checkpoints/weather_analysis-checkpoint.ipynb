# %% [markdown]
# # Welcome to my Weather Analysis!
#
# This is a data analysis project on climate data taken from https://www.ncdc.noaa.gov/cdo-web/search?datasetid=GHCND , featuring an attempts to answer various climate-related questions. I completed a similar project (titled 'California Weather DV'). However, this project is far more in-depth, and incoporates more advanced python techniques and libraries. In this project, I will answer challenge questions from the standpoint of a Meteorological Data Analyst. Enjoy!
#
# Credit: Ideas and challenges by Michele Vallisneri, Theoretical Astrophysicist at NASA and Instructor on LinkedIn learning's "Python Data Analysis" course.

# %%
import math
import collections
import urllib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # How to read the below analysis report
#
# From here and below, the analysis will be split into three sections, 'Explanation', 'Example', and 'Analysis'.
#
# The 'Explanation' and 'Example' sections will show the methods I take to plot the data. The 'Analysis' section will contain my interpretation of the data.
#
# ## I. Explanation
#
# ### After importing the dependencies, retrieve the text files that hold the data I need

# %%
urllib.request.urlretrieve('https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt', 'data/readme.txt')
# Out:
# ('data/readme.txt', <http.client.HTTPMessage at 0x12a3d7090>)

# %%
urllib.request.urlretrieve('https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt', 'data/stations.txt')
# Out:
# ('data/stations.txt', <http.client.HTTPMessage at 0x128c61cd0>)

# %%
stations = np.genfromtxt('data/stations.txt', delimiter=[11,9,10,7,3,31,4,4,6],
                                         names=['id','latitude','longitude','elevation','state','name',
                                                'gsn','hcn','wmo'],
                                         dtype=['U11','d','d','d','U3','U31','U4','U4','U6'],
                                         autostrip=True)

# %% [markdown]
# ### Above, I reformatted the data using NumPy's .genfromtext feature

# %%
len(stations)
# Out:
# 115082

# %% [markdown]
# ### This dataset contains over 115,000 data entries

# %%
plt.plot(stations['longitude'], stations['latitude'], '.', markersize=1)

# %% [markdown]
# ### The chart above is a quick snapshot of the station locations. As we can see, the data we retrieve from the website extends globally.

# %% [markdown]
# # I want to start narrowing my searches down to states and cities. Below is an example of Pasadena (CA), New York City (NY), and San Antonio (TX).

# %%
stations_ca = stations[stations['state'] == 'CA']
plt.plot(stations_ca['longitude'], stations_ca['latitude'], '.', markersize=1)

# %%
stations_ny = stations[stations['state'] == 'NY']
plt.plot(stations_ny['longitude'], stations_ny['latitude'], '.', markersize=1)

# %%
stations_tx = stations[stations['state'] == 'TX']
plt.plot(stations_tx['longitude'], stations_tx['latitude'], '.', markersize=1)

# %% [markdown]
# ### The above shows the station locations at the three states.
#
# However, I would like readings on specific cities. This can be accomplished by finding the specific station located at the city.

# %%
stations[np.char.find(stations['name'], 'NEW YORK') == 0]
# Out:
# array([('US1NYNY0074', 40.7969, -73.933 ,   6.1, 'NY', 'NEW YORK 8.8 N', '', '', ''),
#        ('USC00215902', 46.5233, -95.3847, 428.5, 'MN', 'NEW YORK MILLS', '', '', ''),
#        ('USC00305798', 40.6   , -73.9667,   6.1, 'NY', 'NEW YORK BENSONHURST', '', '', ''),
#        ('USC00305799', 40.8667, -73.8833,  27.1, 'NY', 'NEW YORK BOTANICAL GRD', '', '', ''),
#        ('USC00305804', 40.7333, -73.9333,   3. , 'NY', 'NEW YORK LAUREL HILL', '', '', ''),
#        ('USC00305806', 40.85  , -73.9167,  54.9, 'NY', 'NEW YORK UNIV ST', '', '', ''),
#        ('USC00305816', 40.7   , -74.0167,   3. , 'NY', 'NEW YORK WB CITY', '', '', ''),
#        ('USW00014732', 40.7794, -73.8803,   3.4, 'NY', 'NEW YORK LAGUARDIA AP', '', '', '72503'),
#        ('USW00014786', 40.5833, -73.8833,   4.9, 'NY', 'NEW YORK FLOYD BENNETT FLD', '', '', ''),
#        ('USW00093732', 39.8   , -72.6667,  25.9, 'NY', 'NEW YORK SHOALS AFS', '', '', ''),
#        ('USW00094728', 40.7789, -73.9692,  39.6, 'NY', 'NEW YORK CNTRL PK TWR', '', 'HCN', '72506'),
#        ('USW00094789', 40.6386, -73.7622,   3.4, 'NY', 'NEW YORK JFK INTL AP', '', '', '74486')],
#       dtype=[('id', '<U11'), ('latitude', '<f8'), ('longitude', '<f8'), ('elevation', '<f8'), ('state', '<U3'), ('name', '<U31'), ('gsn', '<U4'), ('hcn', '<U4'), ('wmo', '<U6')])

# %%
stations[np.char.find(stations['name'], 'PASADENA') == 0]
# Out:
# array([('CA1NL000026', 49.0094,  -57.5849,  52.4, 'NL', 'PASADENA 0.5 SE', '', '', ''),
#        ('US1CALA0036', 34.1392, -118.1161, 225.2, 'CA', 'PASADENA 2.0 SE', '', '', ''),
#        ('US1CALA0043', 34.1619, -118.1073, 277.7, 'CA', 'PASADENA 1.8 E', '', '', ''),
#        ('US1CALA0091', 34.1648, -118.1249, 289. , 'CA', 'PASADENA 0.8 ENE', '', '', ''),
#        ('US1MDAA0010', 39.1038,  -76.5443,  13.1, 'MD', 'PASADENA 0.7 SE', '', '', ''),
#        ('US1MDAA0013', 39.1263,  -76.5596,  18.9, 'MD', 'PASADENA 1.1 NNW', '', '', ''),
#        ('US1MDAA0039', 39.0916,  -76.5112,  10.7, 'MD', 'PASADENA 2.6 ESE', '', '', ''),
#        ('US1TXHRR076', 29.6471,  -95.1895,  10.7, 'TX', 'PASADENA 2.4 WSW', '', '', ''),
#        ('US1TXHRR084', 29.6339,  -95.1881,  11.9, 'TX', 'PASADENA 2.8 SW', '', '', ''),
#        ('US1TXHRR093', 29.6849,  -95.2197,   9.1, 'TX', 'PASADENA 4.4 WNW', '', '', ''),
#        ('US1TXHRR094', 29.6746,  -95.2104,   9.1, 'TX', 'PASADENA 3.6 WNW', '', '', ''),
#        ('USC00046719', 34.1483, -118.1447, 263.3, 'CA', 'PASADENA', '', 'HCN', ''),
#        ('USC00416825', 29.7167,  -95.2167,   9.1, 'TX', 'PASADENA HOUSTON', '', '', '')],
#       dtype=[('id', '<U11'), ('latitude', '<f8'), ('longitude', '<f8'), ('elevation', '<f8'), ('state', '<U3'), ('name', '<U31'), ('gsn', '<U4'), ('hcn', '<U4'), ('wmo', '<U6')])

# %%
stations[np.char.find(stations['name'], 'SAN ANTONIO') == 0]
# Out:
# array([('ARM00087784', -40.783 ,  -65.1   ,   20. , '', 'SAN ANTONIO OESTE AERO', '', '', '87784'),
#        ('MXN00003049',  23.8   , -110.05  ,  399.9, '', 'SAN ANTONIO SUR', '', '', ''),
#        ('MXN00003126',  26.5167, -112.5   ,  159.7, '', 'SAN ANTONIO DE LA SIERRA', '', '', ''),
#        ('MXN00003133',  26.1333, -111.45  ,  100. , '', 'SAN ANTONIO NORTE', '', '', ''),
#        ('MXN00005035',  25.2667, -100.5667, 2179.9, '', 'SAN ANTONIO LAS ALAZANAS (DGE', '', '', ''),
#        ('MXN00005049',  25.2833, -100.6167, 2299.7, '', 'SAN ANTONIO LAS ALAZANAS (SMN', '', '', ''),
#        ('MXN00007142',  16.55  ,  -93.4333,  812. , '', 'SAN ANTONIO', '', '', ''),
#        ('MXN00008122',  29.0833, -106.25  , 1529.8, '', 'SAN ANTONIO', '', '', ''),
#        ('MXN00010062',  26.4333, -105.35  , 1654.8, '', 'SAN ANTONIO', '', '', ''),
#        ('MXN00011062',  21.4   , -100.3833, 2279.9, '', 'SAN ANTONIO DE LOS MARTINEZ', '', '', ''),
#        ('MXN00012140',  17.7167, -100.8667, 1899.8, '', 'SAN ANTONIO TEJAS', '', '', ''),
#        ('MXN00015239',  19.75  ,  -99.6333, 2831. , '', 'SAN ANTONIO TROJES', '', '', ''),
#        ('MXN00015341',  19.6667,  -99.6833, 2544.8, '', 'SAN ANTONIO NIXINI', '', '', ''),
#        ('MXN00019159',  23.7333,  -99.9667, 1490.8, '', 'SAN ANTONIO PEA NEVADA', '', '', ''),
#        ('MXN00019180',  24.45  , -100.2333, 1831.8, '', 'SAN ANTONIO EL SALERO', '', '', ''),
#        ('MXN00020104',  17.8667,  -97.45  , 2187.9, '', 'SAN ANTONIO ABAD', '', '', ''),
#        ('MXN00020368',  17.5167,  -97.7167, 2077.8, '', 'SAN ANTONIO MONTEVERDE', '', '', ''),
#        ('MXN00020384',  16.9167,  -97.15  , 2322.9, '', 'SAN ANTONIO HUITEPEC', '', '', ''),
#        ('MXN00021069',  19.5333,  -97.8167, 3064.8, '', 'SAN ANTONIO ARROYO PRIETO (CF', '', '', ''),
#        ('MXN00021070',  18.5   ,  -97.2833, 1860.8, '', 'SAN ANTONIO CAADA', '', '', ''),
#        ('MXN00024063',  21.6833,  -99.4667,  438.9, '', 'SAN ANTONIO DE GUAYABOS', '', '', ''),
#        ('MXN00024191',  23.15  , -101.8833, 2080. , '', 'SAN ANTONIO DEL MEZQUITE', '', '', ''),
#        ('MXN00026042',  27.35  , -108.6667, 1533.8, '', 'SAN ANTONIO', '', '', ''),
#        ('MXN00026284',  28.6167, -109.6   ,  191.7, '', 'SAN ANTONIO DE LA HUERTA', '', '', ''),
#        ('MXN00029019',  19.55  ,  -98.5667, 2614.9, '', 'SAN ANTONIO CALPULALAPAN', '', '', ''),
#        ('MXN00032047',  22.9333, -102.4833, 2172.9, '', 'SAN ANTONIO DEL CIPRES', '', '', ''),
#        ('MXN00032080',  23.8667, -102.5   , 1999.8, '', 'SAN ANTONIO DE TRIANA', '', '', ''),
#        ('US1NMSC0040',  33.8998, -106.8769, 1396.3, 'NM', 'SAN ANTONIO 0.7 S', '', '', ''),
#        ('US1NMSC0046',  33.872 , -106.749 , 1543.8, 'NM', 'SAN ANTONIO 7.4 ESE', '', '', ''),
#        ('US1NMSC0049',  33.9086, -106.8725, 1391.4, 'NM', 'SAN ANTONIO 0.7 SSW', '', '', ''),
#        ('US1TXBXR121',  29.4147,  -98.4959,  199.9, 'TX', 'SAN ANTONIO 3.0 S', '', '', ''),
#        ('US1TXBXR154',  29.4063,  -98.4963,  193.9, 'TX', 'SAN ANTONIO 3.6 S', '', '', ''),
#        ('US1TXBXR169',  29.3032,  -98.4791,  173.1, 'TX', 'SAN ANTONIO 10.8 S', '', '', ''),
#        ('US1TXBXR176',  29.3961,  -98.5606,  208.5, 'TX', 'SAN ANTONIO 5.4 SW', '', '', ''),
#        ('US1TXBXR181',  29.614 ,  -98.5392,  333.5, 'TX', 'SAN ANTONIO 13.3 NNW', '', '', ''),
#        ('US1TXBXR184',  29.5291,  -98.5529,  281.6, 'TX', 'SAN ANTONIO 8.0 NNW', '', '', ''),
#        ('US1TXBXR188',  29.4692,  -98.5883,  258.8, 'TX', 'SAN ANTONIO 5.1 W', '', '', ''),
#        ('US1TXBXR189',  29.5271,  -98.5452,  277.1, 'TX', 'SAN ANTONIO 7.7 NNW', '', '', ''),
#        ('US1TXBXR190',  29.1704,  -98.5282,  214. , 'TX', 'SAN ANTONIO 17.6 S', '', '', ''),
#        ('US1TXBXR203',  29.4347,  -98.6837,  273.4, 'TX', 'SAN ANTONIO 10.8 W', '', '', ''),
#        ('US1TXBXR207',  29.3126,  -98.5248,  184.4, 'TX', 'SAN ANTONIO 10.1 S', '', '', ''),
#        ('US1TXBXR220',  29.3175,  -98.4959,  180.4, 'TX', 'SAN ANTONIO 9.7 S', '', '', ''),
#        ('US1TXBXR271',  29.311 ,  -98.5001,  182.9, 'TX', 'SAN ANTONIO 10.1 S', '', '', ''),
#        ('US1TXBXR303',  29.4929,  -98.6822,  262.7, 'TX', 'SAN ANTONIO 10.9 WNW', '', '', ''),
#        ('US1TXBXR310',  29.4925,  -98.7181,  280.4, 'TX', 'SAN ANTONIO 13.0 W', '', '', ''),
#        ('US1TXBXR314',  29.5325,  -98.5103,  274.9, 'TX', 'SAN ANTONIO 5.2 N', '', '', ''),
#        ('US1TXBXR319',  29.4504,  -98.5275,  211.5, 'TX', 'SAN ANTONIO 1.4 WSW', '', '', ''),
#        ('US1TXBXR327',  29.4194,  -98.6401,  231.6, 'TX', 'SAN ANTONIO 8.5 WSW', '', '', ''),
#        ('US1TXBXR328',  29.5161,  -98.522 ,  242.3, 'TX', 'SAN ANTONIO 4.2 NNW', '', '', ''),
#        ('US1TXBXR343',  29.3474,  -98.4601,  170.7, 'TX', 'SAN ANTONIO 8.1 SSE', '', '', ''),
#        ('US1TXBXR348',  29.422 ,  -98.7366,  259.1, 'TX', 'SAN ANTONIO 14.1 W', '', '', ''),
#        ('US1TXBXR359',  29.3277,  -98.4306,  173.7, 'TX', 'SAN ANTONIO 10.1 SSE', '', '', ''),
#        ('US1TXBXR362',  29.5671,  -98.535 ,  275.5, 'TX', 'SAN ANTONIO 7.8 NNW', '', '', ''),
#        ('US1TXBXR367',  29.5364,  -98.4971,  275.2, 'TX', 'SAN ANTONIO 5.5 N', '', '', ''),
#        ('US1TXBXR383',  29.4411,  -98.7018,  259.7, 'TX', 'SAN ANTONIO 11.9 W', '', '', ''),
#        ('US1TXBXR390',  29.3792,  -98.3751,  192.6, 'TX', 'SAN ANTONIO 9.5 SE', '', '', ''),
#        ('US1TXBXR396',  29.4576,  -98.534 ,  214.9, 'TX', 'SAN ANTONIO 1.7 W', '', '', ''),
#        ('US1TXBXR400',  29.448 ,  -98.722 ,  271. , 'TX', 'SAN ANTONIO 13.1 W', '', '', ''),
#        ('US1TXBXR402',  29.4952,  -98.6739,  263.7, 'TX', 'SAN ANTONIO 10.5 WNW', '', '', ''),
#        ('USC00047711',  34.1667, -117.6667,  729.1, 'CA', 'SAN ANTONIO CN MOUTH', '', '', ''),
#        ('USC00047714',  36.0167, -121.25  ,  323.1, 'CA', 'SAN ANTONIO MISSION', '', '', ''),
#        ('USC00267254',  38.3   , -117.0667, 1828.8, 'NV', 'SAN ANTONIO', '', '', ''),
#        ('USC00297804',  35.9667, -106.4833, 2590.8, 'NM', 'SAN ANTONIO CREEK', '', '', ''),
#        ('USC00417947',  29.4703,  -98.4728,  213.4, 'TX', 'SAN ANTONIO INCARNATE WORD', '', '', ''),
#        ('USC00417948',  29.3   ,  -98.4667,  180.1, 'TX', 'SAN ANTONIO NURSERY', '', '', ''),
#        ('USC00418169',  29.4508,  -98.7028,  286.5, 'TX', 'SAN ANTONIO/SEAWORLD', '', '', ''),
#        ('USW00012909',  29.3833,  -98.5833,  207.9, 'TX', 'SAN ANTONIO KELLY AFB', '', '', ''),
#        ('USW00012921',  29.5442,  -98.4839,  240.5, 'TX', 'SAN ANTONIO INTL AP', 'GSN', 'HCN', '72253'),
#        ('USW00012931',  29.35  ,  -98.45  ,  182. , 'TX', 'SAN ANTONIO BROOKS AFB', '', '', ''),
#        ('USW00012970',  29.3389,  -98.4719,  174. , 'TX', 'SAN ANTONIO STINSON AP', '', '', ''),
#        ('VEM00080447',   7.841 ,  -72.44  ,  399.9, '', 'SAN ANTONIO DEL TACHIRA', '', '', '80447')],
#       dtype=[('id', '<U11'), ('latitude', '<f8'), ('longitude', '<f8'), ('elevation', '<f8'), ('state', '<U3'), ('name', '<U31'), ('gsn', '<U4'), ('hcn', '<U4'), ('wmo', '<U6')])

# %% [markdown]
# ### Although there are several stations we can choose to gather data, I want the data from the quality-controlled HCN (Historical Climatology Network) database. This will ensure that I have the measurements I need to perform the analysis.
#
# According to the searches above, I would be using the below stations:
#
# Pasadena, CA = USC00046719 | New York City, New York = USW00094728 | San Antonio, Texas = USW00012921

# %%
urllib.request.urlretrieve('https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/all/USC00046719.dly', 'data/PASADENA.dly')
# Out:
# ('data/PASADENA.dly', <http.client.HTTPMessage at 0x123dfc090>)

# %%
urllib.request.urlretrieve('https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/all/USW00094728.dly', 'data/NEWYORK.dly')
# Out:
# ('data/NEWYORK.dly', <http.client.HTTPMessage at 0x128a93410>)

# %%
urllib.request.urlretrieve('https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/all/USW00012921.dly', 'data/TEXAS.dly')
# Out:
# ('data/TEXAS.dly', <http.client.HTTPMessage at 0x129009790>)

# %%
import getweather

# %% [markdown]
# ## II. Example: Pasadena, CA
#
# Before jumping into the analysis, I want to show the steps that I take to plot the charts. This will show you what methods I take to validate the data, and express it in a meaningful way.
#
# Below I start gathering the data of Pasadena's climates, and create a simple plot to see the maximum temperatures recorded at Pasadena for 2019.

# %%
pasadena = getweather.getyear('PASADENA', ['TMIN','TMAX'], 2019)

# %%
np.mean(pasadena['TMAX']), np.min(pasadena['TMAX']), np.max(pasadena['TMAX'])
# Out:
# (24.971780821917804, 10.0, 38.3)

# %%
plt.plot(pasadena['TMAX'])

for value in [np.mean(pasadena['TMAX']), np.min(pasadena['TMAX']), np.max(pasadena['TMAX'])]:
    plt.axhline(value, linestyle=':')

# %% [markdown]
# ### In its most simplest form, this graph shows the maximum temperatures throughout all 365 days at the Pasadena station.
#
# According to the graph, the temperature increases around the late 100's to early 300's. This can seem obvious due to summer temperatures.

# %%
rain = getweather.getyear('PASADENA', ['PRCP'], 2019)['PRCP']

# %%
plt.plot(rain)

# %% [markdown]
# ### I wanted to see how much precipitation Pasadena experienced throughout the year. This simple graph shows that Pasadena mainly experiences some form of precipitation during the Winter.
#
# Unfortunately, the chart(s) shown above have a large variance because the changes is temperature can vary greatly after each day. This causes noise in the dataset that can offset trends. To remedy this, I normalize the values so that the array values sum to 1.

# %%
plt.plot(pasadena['TMAX'], '.', ms=5)
plt.plot(np.correlate(pasadena['TMAX'], np.ones(10)/10, 'valid'))

# %% [markdown]
# ### The above graph shows the original maximum temperatures chart in small dots. However, this time I added in a correlated orange line that shows the values of a normalized set of arrays. In other words, the orange line indicates the 'validated' temperatures throughout those days, thereby showing a 'trend'.

# %%
def smooth(array, window=10, mode='valid'):
    return np.correlate(array, np.ones(window)/window, mode)

# %%
plt.plot(pasadena['TMIN'], '.', ms=5)
plt.plot(smooth(pasadena['TMIN'], 10))

plt.plot(pasadena['TMAX'], '.', ms=5)
plt.plot(smooth(pasadena['TMAX'], 10))

# %% [markdown]
# ### This chart shows the maximum and minimum temperatures of Pasadena in 2019.
#
# Now that I've shown the in-depth methods of how I extract, plot, and smooth the data, I can combine these methods into functions that can be applied to multiple stations.

# %% [markdown]
# # Analysis: California Weather Patterns
#
# Now that I've gathered the data and visualized it in a meaningful way, I can create functions to apply the same methods to multiple cities.
#
# I will be using the 'smooth' function above, the 'plotsmooth' function below, and the 'fillnans' function to remove any NaN values.

# %%
def plotsmooth(station, year):
    stationdata = getweather.getyear(station, ['TMIN','TMAX'], year)

    for obs in ['TMIN','TMAX']:   
        stationdata[obs] = fillnans(stationdata[obs])
    
        plt.plot(stationdata[obs], '.', ms=1)
        plt.plot(range(10,356), smooth(stationdata[obs], 20))
    
    plt.title(station)
    plt.axis(xmin=1, xmax=365, ymin=-10, ymax=45)

# %%
def fillnans(array):
    x = np.arange(len(array))
    good = ~np.isnan(array)

    return np.interp(x, x[good], array[good])

# %%
plotsmooth('PASADENA', 2019)
plotsmooth('PASADENA', 2018)
plotsmooth('PASADENA', 2017)

plt.axis(ymin=0,ymax=40)
# Out:
# (1.0, 365.0, 0, 40)

# %% [markdown]
# ### Testing the functions on Pasadena
#
# I use the smooth function inside the plotsmooth function to iterate through all the data points for each station and plot them in a normalized way to 'line' the trend. The trends are indicated by different colors to represent the temperature minimum and maximum of each station.
#
# In the example above, the minimum temperatures of Pasadena are closely correlated to one another. Meaning, throughout the years 2017-2019, the minimum temperatures follow a similar trend where days 150-300 experience an increases in minimum temperature.
#
# Although the maximum temperatures of Pasadena 2017-2019 indicate a similar trends, they trend experiences more variance than that of minimum temperatures. For example, around day 50-70, the orange line skyrockets to a maximum temperature that is higher than the other two years around that same time of the year. Also, it seems that maximum temperatures vary greatly throughout as sudden spikes in temperature are seen on certain days for one year, but not on the same day in a different year.

# %% [markdown]
# ### Now that I've tested the functions on Pasadena (successfully), I can create a FOR loop that iterates through multiple cities using the same functions above.

# %%
plt.figure(figsize=(20,15))

for i, city in enumerate(['PASADENA','NEW YORK','HILO','SAN ANTONIO']):
    plt.subplot(2,2,i+1)
    plotsmooth(city, 2019)
    plotsmooth(city, 2018)
    plotsmooth(city, 2017)
    plotsmooth(city, 2016)
    plotsmooth(city, 2015)
    plotsmooth(city, 2014)
    plotsmooth(city, 2013)
    plotsmooth(city, 2012)

# %% [markdown]
# ### Pasadena, CA:
# As mentioned in the aforementioned example (test), Pasadena experiences a regular pattern that coincides with higher temperatures around days 150-300. The trend is much 'tighter' for minimum temperatures, and maximum temperatures seem to have more variance throughout the years.
#
# ### New York, NY:
# Like Pasadena, New York seems to follow a similar pattern during summer. Days 125-280 experience higher temperatures. Unlike Pasadena, however, New York experiences winters that are below 0. And in some years, the minimum temperatures of one year are 'higher' that the maximum temperatures of another year. One thing to note here is that the TMIN and TMAX data points are MUCH closer than that of Pasadena. This makes daily weather predictions more accurate in New York (I.E. LOW 63, HIGH 96 vs. LOW 74 vs. HIGH 84)
#
# ### Hilo, HI:
# Hilo, Hawaii can be considered the 'odd-one-out'. Unlike the other charts, Hilo experiences temperatures that are... Uneventful. The island state has a consistent trend of warm weather throughout the year. Although the TMIN and TMAX spread is farther apart compared to New York, the temperatures do not have as strong fluctuation throughout the year.
#
# ### San Antonio, Texas:
# San Antonio, Texas has a trend that is extremely similar to that of New York, having a the same shape throughout the year depending on the season. However, the earlier and later days of the year are more like Pasadena's. It is important to note that throughout 2012-2019, the summers have been quite regular, but the winters (days 0-60, days 300-360) vary greater than other cities.

# %%
plt.figure(figsize=(20,15))

for i, city in enumerate(['GREENSBORO','WASHINGTON','THREE LYNX','JACKSONVILLE']):
    plt.subplot(2,2,i+1)
    plotsmooth(city, 2019)
    plotsmooth(city, 2018)
    plotsmooth(city, 2017)
    plotsmooth(city, 2016)
    plotsmooth(city, 2015)
    plotsmooth(city, 2014)
    plotsmooth(city, 2013)
    plotsmooth(city, 2012)

# %% [markdown]
# ### Greensboro, NC:
# I wanted to report findings on the mid-east side of the United States to see if there was any differece from the numbers reported from New York. Although the minimum and maximum temperatures presented are similar to that of New York, there is a fair amount of variance between the years. Summers are showing similar temperatures, but winter temperatures are scattered compared to New York. Could it be because NC is closer to the equator? Lets do more tests.
#
# ### Washington, Iowa:
# I also wanted to get temperatures of states that were in the middles of the United States of America. The NOAA supplied me with a station in Washington, Iowa. The trend here resembles that of New York, give or take varying winter temperatures. The shape almost mimcs that of NY. Note that NY and Iowa share close latitudinal positions. Perhaps this explains why the temperatures mirror one another.
#
# ### Three Lynx, Oregon:
# Just like Hilo, the chart shows an odd pattern compared to previous analyses. The most important thing to note here is that California and Oregon share longetidunal positioning, and yet their resulting trends are quite different. Perhaps latitudinal positioning plays an important role in having uniform weather (as depicted in Iowa vs. NY), and longetidunal has a 'weaker' affect on keeping similar weather patterns (depicted in Oregon vs. CA).
#
# ### Jacksonville, FL:
# Jacksonville, Florida has, by far, the largest difference between the minimum temperature and max temperature of years 2012-2019. Not only is the variance of the years staggering all over the chart, but temperatures start at sub-zero and can skyrocket to temperatures that rival Pasadena summers. This chart also supports the previous hypothesis that the closer a station is to the equator, the more variance the chart will report.
